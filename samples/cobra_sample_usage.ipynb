# %% [markdown]
# ## Install

# %% [markdown]
# Clone this repo.
#
# - In a command line or shell, navigate to the cloned repo.
# - `pip install -e ./cobrapy`

# %%
# %pip install -e ../.

# %% [markdown]
# ## Standard Example

# %% [markdown]
# ### Step #0 - Load Environment Variables

# %% [markdown]
# This utility depends on connections to outside services. You will neeed to make sure the following environment variables are set.
#
# ```
# AZURE_OPENAI_GPT4_VISION_API_KEY=""
# AZURE_OPENAI_GPT4_VISION_ENDPOINT=""
# AZURE_OPENAI_GPT4_VISION_API_VERSION="2024-06-01"
# AZURE_OPENAI_GPT4_VISION_DEPLOYMENT=""
#
#
# AZURE_OPENAI_WHISPER_API_KEY=""
# AZURE_OPENAI_WHISPER_ENDPOINT=""
# AZURE_OPENAI_WHISPER_API_VERSION="2024-06-01"
# AZURE_OPENAI_WHISPER_DEPLOYMENT=""
# AZURE_OPENAI_WHISPER_DEPLOYMENT="whisper-001"
# ```
#
# One way to do this is to create a `.env` file and use a utility such as python-dotenv to load it. You can copy or rename the `sample.env` file and fill it with your own values.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Step #1 - Create a VideoClient object

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd()))

from cobrapy import VideoClient

client = VideoClient(video_path="C:\\videos\\PCL2.mp4")
client.manifest.model_dump()
# Out:
# {'name': 'PCL2.mp4',
#  'video_manifest_path': None,
#  'source_video': {'path': 'C:\\videos\\PCL2.mp4',
#   'video_found': True,
#   'size': [1920, 1080],
#   'rotation': 0,
#   'fps': 23.976023976023978,
#   'duration': 109.82,
#   'nframes': 2634,
#   'audio_found': True,
#   'audio_duration': 109.82,
#   'audio_fps': 44100},
#  'processing_params': {'output_directory': None,
#   'segment_length': None,
#   'fps': None,
#   'generate_transcript_flag': True,
#   'trim_to_nearest_second': False,
#   'allow_partial_segments': True},
#  'segment_metadata': {'effective_duration': None, 'num_segments': None},
#  'segments': [],
#  'final_summary': None,
#  'audio_transcription': None,
#  'source_audio': {'path': None, 'file_size_mb': None}}

# %% [markdown]
# ### Step #2 - Preprocess Video

# %%
# client.preprocess_video(overwrite_output=True)
# client.manifest.model_dump()
client.preprocess_video(
    #output_directory="./output_dir",  # control where to save the manifest and other files
    segment_length=10,  # how long should each segment be in seconds
    fps=1,  # how many frames per second to sample from the video (i.e. 1 = 1 frame per second, 1/3 = 1 frame per 3 seconds)
    max_workers=5,  # how many threads to use for processing. Default is to use number of cores minus 1.
    allow_partial_segments=True,  # if False, the last segment will be discarded if it is shorter than segment_length
    overwrite_output=True,  # any files in a directory with the same name will be overwritten
)
# Out:
# (0.0ss) Preprocessing video PCL2.mp4
# (0.0s)Setting processing parameters...
# (0.0ss) Preparing output directory
# (0.0ss) Generating segments...
# (0.0ss) Extracting audio...
# (10.1ss) Processing segments...
# **Segment 0 seg1_start0s_end10s - beginning processing. Transcripts: True
# **Segment 1 seg2_start10s_end20s - beginning processing. Transcripts: True
# **Segment 2 seg3_start20s_end30s - beginning processing. Transcripts: True
# **Segment 3 seg4_start30s_end40s - beginning processing. Transcripts: True
# **Segment 4 seg5_start40s_end50s - beginning processing. Transcripts: True
# **Segment 0 seg1_start0s_end10s - extracted frames in 15.3s
# **Segment 5 seg6_start50s_end60s - beginning processing. Transcripts: True
# **Segment 2 seg3_start20s_end30s - extracted frames in 16.9s
# **Segment 6 seg7_start60s_end70s - beginning processing. Transcripts: True
# **Segment 1 seg2_start10s_end20s - extracted frames in 17.8s
# **Segment 7 seg8_start70s_end80s - beginning processing. Transcripts: True
# **Segment 4 seg5_start40s_end50s - extracted frames in 18.3s
# **Segment 8 seg9_start80s_end90s - beginning processing. Transcripts: True
# **Segment 3 seg4_start30s_end40s - extracted frames in 18.4s
# **Segment 9 seg10_start90s_end100s - beginning processing. Transcripts: True
# **Segment 6 seg7_start60s_end70s - extracted frames in 15.9s
# **Segment 10 seg11_start100s_end109.82s - beginning processing. Transcripts: True
# **Segment 5 seg6_start50s_end60s - extracted frames in 18.7s
# **Segment 7 seg8_start70s_end80s - extracted frames in 16.5s
# **Segment 8 seg9_start80s_end90s - extracted frames in 16.6s
# **Segment 9 seg10_start90s_end100s - extracted frames in 18.3s
# **Segment 10 seg11_start100s_end109.82s - extracted frames in 13.9s
# (56.8ss) All segments pre-processed
# Video manifest for PCL2.mp4 saved to .\PCL2_mp4_1.00fps_10sSegs_cobra\_video_manifest.json
# '.\\PCL2_mp4_1.00fps_10sSegs_cobra\\_video_manifest.json'

# %% [markdown]
# ### Step #3 - Run an Analysis

# %%
from cobrapy.analysis import BasicSummary,ActionSummary

action_config = ActionSummary()
# action_config.system_prompt_lens="Your lens here"
# action_config.results_template=[{{"start_timestamp":"0s","end_timestamp":"10s","actions":"Your action here","summary":"description"}}]
action_summary = client.analyze_video(analysis_config=action_config,run_async=True,max_concurrent_tasks=10)
action_summary
# Out:
# Starting video analysis: "BaseAnalysis" for PCL2.mp4
# Populating prompts for each segment
# Generating prompt for segment seg1_start0s_end10s
# Generating prompt for segment seg2_start10s_end20s
# Generating prompt for segment seg3_start20s_end30s
# Generating prompt for segment seg4_start30s_end40s
# Generating prompt for segment seg5_start40s_end50s
# Generating prompt for segment seg6_start50s_end60s
# Generating prompt for segment seg7_start60s_end70s
# Generating prompt for segment seg8_start70s_end80s
# Generating prompt for segment seg9_start80s_end90s
# Generating prompt for segment seg10_start90s_end100s
# Generating prompt for segment seg11_start100s_end109.82s
# Running analysis asynchronously
# Starting analysis for segment seg1_start0s_end10s
# Generating prompt for segment seg1_start0s_end10s
# Starting analysis for segment seg2_start10s_end20s
# Generating prompt for segment seg2_start10s_end20s
# Starting analysis for segment seg3_start20s_end30s
# Generating prompt for segment seg3_start20s_end30s
# Starting analysis for segment seg4_start30s_end40s
# Generating prompt for segment seg4_start30s_end40s
# Starting analysis for segment seg5_start40s_end50s
# Generating prompt for segment seg5_start40s_end50s
# Starting analysis for segment seg6_start50s_end60s
# Generating prompt for segment seg6_start50s_end60s
# Starting analysis for segment seg7_start60s_end70s
# Generating prompt for segment seg7_start60s_end70s
# Starting analysis for segment seg8_start70s_end80s
# Generating prompt for segment seg8_start70s_end80s
# Starting analysis for segment seg9_start80s_end90s
# Generating prompt for segment seg9_start80s_end90s
# Starting analysis for segment seg10_start90s_end100s
# Generating prompt for segment seg10_start90s_end100s
# Segment seg1_start0s_end10s analyzed in 25.331 seconds
# Starting analysis for segment seg11_start100s_end109.82s
# Generating prompt for segment seg11_start100s_end109.82s
# Segment seg3_start20s_end30s analyzed in 50.773 seconds
# Segment seg9_start80s_end90s analyzed in 49.088 seconds
# Segment seg11_start100s_end109.82s analyzed in 28.844 seconds
# Segment seg5_start40s_end50s analyzed in 52.957 seconds
# Segment seg7_start60s_end70s analyzed in 53.407 seconds
# Segment seg10_start90s_end100s analyzed in 54.163 seconds
# Segment seg8_start70s_end80s analyzed in 58.13 seconds
# Segment seg4_start30s_end40s analyzed in 60.241 seconds
# Segment seg6_start50s_end60s analyzed in 59.331 seconds
# Segment seg2_start10s_end20s analyzed in 69.379 seconds
# Writing results to .\PCL2_mp4_1.00fps_10sSegs_cobra\_video_analysis_results_BaseAnalysis.json
# Video analysis completed in 72.281: "BaseAnalysis" for PCL2.mp4
# Video manifest for PCL2.mp4 saved to .\PCL2_mp4_1.00fps_10sSegs_cobra\_video_manifest.json
# [[{'start_timestamp': '0.0s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '5.56s',
#    'scene_theme': 'Natural and Recreational',
#    'characters': 'Boy and girl playing; Two people in the water; Individual drinking water.',
#    'summary': 'The video starts with a narration about water usage, highlighting it as a vital resource. The visuals transition from natural water bodies to playful and recreational scenes involving water. A child is splashing water using a hose, individuals float in a clear pool, and a person drinks bottled water against a backdrop of city skyline.',
#    'actions': 'Children playing with water hose; Individuals relaxing in a pool; Adult drinking water from a bottle.',
#    'key_objects': 'Green lush area with trees and water; Yellow hose spraying water; Swimwear; Clear bottled water; Cityscape including tall buildings.'},
#   {'start_timestamp': '5.56s',
#    'sentiment': 'Positive',
#    'end_timestamp': '10.0s',
#    'scene_theme': 'Everyday Life and Leisure',
#    'characters': 'Child drinking from water fountain; Couple walking; Family fishing.',
#    'summary': 'This segment features everyday activities that emphasize the importance of water in leisure and daily life. A child drinks from a public water fountain. A couple enjoys a walk along a riverside walkway. In another frame, a family is shown fishing by a lake under the warm glow of evening sun.',
#    'actions': 'Child drinking water; Couple walking side-by-side; Family posing with fishing gear.',
#    'key_objects': 'Public water fountain; Riverside walkway with railings; Fishing rods and net; Apples with water drops; Tall urban buildings in the distance.'}],
#  [{'start_timestamp': '10.0s',
#    'end_timestamp': '15.56s',
#    'sentiment': 'Neutral',
#    'scene_theme': 'Nature and Leisure',
#    'characters': 'Man in hat, child in hat, young woman by the water',
#    'summary': 'The video begins with close-up shots of apples glistening with water droplets, suggesting freshness and natural beauty. It transitions to a scene of a man and a child at a lakeside, possibly indicating a fishing activity. Another scene shows a young woman walking beside a waterfront, basking in the leisurely atmosphere. The audio highlights facts about water usage in North America.',
#    'actions': 'Apples are being sprayed with water. A man, holding a fishing net, stands with a child who is holding a fishing rod beside a lake. A couple walks along a waterfront pathway, enjoying a moment together.',
#    'key_objects': 'Red apples with water droplets, scenic waterfront with buildings, fishing net, fishing rod, child wearing a plaid shirt and hat, man in a cowboy hat and plaid shirt, couple on a walkway, the woman wearing a white sleeveless shirt, and man in a gray T-shirt.'},
#   {'start_timestamp': '15.56s',
#    'end_timestamp': '20.0s',
#    'sentiment': 'Neutral',
#    'scene_theme': 'Daily Life and Water',
#    'characters': 'Young woman, unidentified person pouring water',
#    'summary': 'A drone shot captures the mesmerizing movement of ocean waves, symbolizing the expanse and power of water. This is followed by a scene depicting an individual pouring water from a pitcher into a glass, representative of daily water consumption. The audio adds context by discussing water usage statistics.',
#    'actions': 'Ocean waves move rhythmically in a captivating overhead view. Water is being poured from a pitcher into a glass in a domestic setting.',
#    'key_objects': 'Vast ocean waves, clear glass pitcher, drinking glass, individual wearing a navy blue shirt and white undershirt, indoor setting with a reflective surface.'}],
#  [{'start_timestamp': '20.0s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '24.0s',
#    'scene_theme': 'Industrial, Environmental',
#    'characters': 'Hand of a person pouring water',
#    'summary': 'A person pours water from a pitcher into a clear glass. The action shifts to a natural setting with water flowing over rocks, possibly symbolizing the natural water cycle.',
#    'actions': 'Pouring water into a glass; flowing water imagery illustrating natural water movement.',
#    'key_objects': 'Clear glass, hand supporting glass, pitcher with water, flowing river with rocks and leaves submerged.'},
#   {'start_timestamp': '24.0s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '30.0s',
#    'scene_theme': 'Construction, Industrial',
#    'characters': 'Construction workers near large machinery and equipment',
#    'summary': 'The scene transitions to a construction site where large machinery is actively lifting substantial components. A workforce is overseeing the operations, demonstrating active industrial construction work related to water management or infrastructure.',
#    'actions': 'Cranes lifting industrial components; workers observing and coordinating the large-scale construction activities.',
#    'key_objects': 'Yellow crane, construction components, workers wearing helmets and safety vests, high-pressure water outflow, industrial construction landscape.'}],
#  [{'start_timestamp': '30s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '34.44s',
#    'scene_theme': 'Informative',
#    'characters': 'No people visible, industrial infrastructure visible',
#    'summary': 'The video segment showcases various water infrastructure components. The audio discusses the role of water infrastructure in communities, emphasizing its importance. Visually, the cameras focus on different structural aspects and water management systems.',
#    'actions': 'The camera moves through different scenes of water infrastructure, including a dam, steel structures, and large pipes.',
#    'key_objects': 'Dam with cascading water, white and geometric steel structures, blue cylindrical tank, mountainous backdrop, pipeline system under construction.'},
#   {'start_timestamp': '35.56s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '40s',
#    'scene_theme': 'Industrial',
#    'characters': 'No people visible, industrial work area',
#    'summary': "The segment continues showcasing water management facilities. The focus shifts to more complex setups, illustrating tanks, reservoirs, and other industrial equipment, while the narration emphasizes infrastructure's critical role.",
#    'actions': 'The camera pans through the industrial site, highlighting the construction and operational aspects of the water treatment facility.',
#    'key_objects': 'Modern bridge over water, extensive round water tanks, cranes, construction vehicles, muddy and earthy work area, white surfaces with structural elements.'}],
#  [{'start_timestamp': '40.0s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '44.44s',
#    'scene_theme': 'Industrial, Infrastructure',
#    'characters': 'Two people in hard hats and vests near equipment.',
#    'summary': 'The segment shows an industrial water facility, focusing on infrastructure relating to water management. Two individuals in protective gear are discussing or inspecting the large pipes and pumping equipment. The facility appears to be a part of a water distribution system.',
#    'actions': 'The two individuals appear to be observing or discussing the operations near the pumps and pipes.',
#    'key_objects': 'Large beige pipes with valves and gauges; two individuals wearing safety vests and helmets; fenced industrial building in the background.'},
#   {'start_timestamp': '44.44s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '50.0s',
#    'scene_theme': 'Construction, Development',
#    'characters': 'Construction workers in safety gear.',
#    'summary': 'The scene transitions to a construction site, emphasizing the development aspect of water infrastructure. Workers are involved in pouring and handling concrete, indicating ongoing construction or maintenance work.',
#    'actions': 'Construction workers are pouring concrete on the site, suggesting active development or repair work.',
#    'key_objects': 'Concrete being poured and smoothed by workers wearing heavy-duty boots and gloves; construction machinery such as an excavator; muddy construction attire.'}],
#  [{'start_timestamp': '50.0s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '52.22s',
#    'scene_theme': 'Industrial Work',
#    'characters': 'Workers in construction attire',
#    'summary': 'Workers are actively pouring and leveling concrete at a construction site. The ground is wet from the freshly poured concrete, suggesting active foundation work.',
#    'actions': 'Pouring concrete, leveling the surface.',
#    'key_objects': 'Workers wearing orange and yellow safety vests, blue jeans, knee-high boots. Construction equipment is visible and being used for concrete pouring.'},
#   {'start_timestamp': '51.11s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '60.0s',
#    'scene_theme': 'Infrastructure and Development',
#    'characters': 'Distant construction workers and vehicles',
#    'summary': 'The scene shifts to a large water treatment facility with several tanks and pipes. Workers are inspecting and possibly working on infrastructure. The focus is on the expansive layout of the facility, indicating modern infrastructure for water management.',
#    'actions': 'Inspection, maintenance of the water facility.',
#    'key_objects': 'Multiple tanks, pipelines, railings, and walkways. Workers wearing safety gear are seen in the distance. Vehicles and construction equipment parked nearby.'}],
#  [{'start_timestamp': '60.0s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '65.56s',
#    'scene_theme': 'Industrial',
#    'characters': 'No visible people',
#    'summary': 'The scene focuses on a water treatment facility, showcasing a large water basin with several ducks swimming. The facility is equipped with modern infrastructure including bridges and pipes. The transcription highlights the purpose of the facility: treating and recycling wastewater.',
#    'actions': 'No people actions; ducks are swimming in the water.',
#    'key_objects': 'Water basin with sparkling water, metal bridge with rails, several ducks swimming, pink and metallic pipes, distant buildings, open sky.'},
#   {'start_timestamp': '65.56s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '70.0s',
#    'scene_theme': 'Industrial',
#    'characters': 'Workers on rooftop, industrial setting',
#    'summary': 'The video transitions to aerial views of water treatment facilities, with complex structures visible. This includes several basins and buildings. The final frame shows a large white rooftop with two workers, suggesting ongoing maintenance or construction work. In the distance, a suburban area can be seen.',
#    'actions': 'Two workers on the rooftop appear to be performing maintenance tasks.',
#    'key_objects': 'Multiple large basins viewed from above, concrete structures, two workers on white rooftop, suburban landscape in the background, construction equipment near the building.'}],
#  [{'start_timestamp': '70.0s',
#    'sentiment': 'Positive',
#    'end_timestamp': '73.33s',
#    'scene_theme': 'Dramatic',
#    'characters': 'Construction workers, office meeting attendees',
#    'summary': 'The sequence begins with an aerial view of a construction site. Two workers, clad in safety vests, are working on a large circular structure. The scene shifts to a meeting in an office where people are engaged in discussion, likely discussing plans related to construction or projects.',
#    'actions': 'Workers inspect and work on the structure. In the office, individuals are likely discussing plans and strategies.',
#    'key_objects': 'Circular construction site with white surface, workers in safety vests. Office setting with large table, laptops, pens.'},
#   {'start_timestamp': '74.44s',
#    'sentiment': 'Neutral',
#    'end_timestamp': '80.0s',
#    'scene_theme': 'Emotional, Heartfelt',
#    'characters': 'Kayaker, child with guardian, engineers at a site, group examining equipment',
#    'summary': 'Images show a kayaker in a green kayak on calm waters, emphasizing recreation and tranquility. Another scene shows a child being helped with gardening by an adult. The sequence concludes with an engineer at an industrial site and a group of people examining technical equipment at an event.',
#    'actions': 'Kayaker paddles across serene water. An adult assists a child with a garden hose. An engineer examines infrastructure components. A group engages with gathered technical equipment.',
#    'key_objects': 'Green kayak on water. Garden setting with hose, child in red and white shirt, adult in white shirt. Industrial site with beige equipment and engineer in vest. Technical equipment with attendees in blue and leather jackets.'}],
#  [{'start_timestamp': '80.0s',
#    'end_timestamp': '83.33s',
#    'sentiment': 'Neutral',
#    'scene_theme': 'Professional, Industrial',
#    'characters': 'People in professional attire with hard hats and safety vests.',
#    'summary': 'The video begins in a professional setting. Several individuals are interacting, likely discussing work-related topics, consistent with the audio about consultants and tradespeople collaborating. The scene transitions to various environments with individuals in hard hats, implying construction or industrial settings.',
#    'actions': 'Hand gestures in discussion, individual standing in a construction area.',
#    'key_objects': "Tools on display, blue coat and jeans of individuals, safety equipment including hard hats and vests visible with labels 'NORDIC PCL', 'PCL'. Several industrial backgrounds visible in different frames."},
#   {'start_timestamp': '84.44s',
#    'end_timestamp': '86.67s',
#    'sentiment': 'Positive',
#    'scene_theme': 'Daily Life',
#    'characters': 'Individuals depicted within domestic settings.',
#    'summary': 'The focus shifts to daily water usage. A person fills a glass at a chrome faucet, showcasing practical aspects of water accessibility.',
#    'actions': 'Turning on a faucet, filling a glass with water.',
#    'key_objects': "Chrome tap labeled 'H', clear glass."},
#   {'start_timestamp': '86.67s',
#    'end_timestamp': '90.0s',
#    'sentiment': 'Positive',
#    'scene_theme': 'Recreation',
#    'characters': 'A person involved in outdoor activities with an animal, individual engaging in water sports.',
#    'summary': 'In a leisure setting, a young woman is watering a dog with a garden hose outside. Later, an individual participates in a water sport, showcasing enjoyment and connection with water in recreational activities.',
#    'actions': 'Watering a dog with a hose, wakeboarding on the water.',
#    'key_objects': 'Garden hose, a large black dog, person in a black wetsuit and red boots, engaging in wakeboarding with a bridge in the background.'}],
#  [{'start_timestamp': '90.0s',
#    'end_timestamp': '92.22s',
#    'sentiment': 'Positive',
#    'scene_theme': 'Energetic',
#    'characters': 'Wakeboarder',
#    'summary': 'The scene captures an individual actively wakeboarding on a body of water. The energy and enthusiasm are evident as they hold onto the rope with precision, showcasing their skill. The background features a bridge and some greenery.',
#    'actions': 'The person is wakeboarding, riding the waves with expertise and using the rope to maintain balance and momentum.',
#    'key_objects': 'Wakeboard, rope handle, black wetsuit, red bindings, body of water, bridge in the background, vegetation.'},
#   {'start_timestamp': '92.22s',
#    'end_timestamp': '100.0s',
#    'sentiment': 'Neutral',
#    'scene_theme': 'Dynamic and Constructive',
#    'characters': 'Mother and child, construction workers',
#    'summary': 'A tender moment is depicted with a mother and child at sunset by the sea, reflecting warmth and connection. This transitions to a construction site, illustrating various activities related to infrastructure development.',
#    'actions': "The mother and child are interacting warmly by the water's edge. In the construction scenes, workers are engaged in handling machinery and rebar installations.",
#    'key_objects': 'Mother and child by the sea, sunset, boats. Construction site with workers wearing safety gear, rebar structure, cranes, industrial facilities.'}],
#  [{'start_timestamp': '100.0s',
#    'end_timestamp': '104.36s',
#    'sentiment': 'Neutral',
#    'scene_theme': 'Industrial',
#    'characters': 'None',
#    'summary': 'The sequence begins with an aerial view of a large circular water treatment facility. The structure has several divisions with green sections, indicative of a water processing area. The scene transitions to a close-up of an industrial setup, focusing on a machine within a fenced area.',
#    'actions': 'No visible actions by people. The camera captures the infrastructure of the water treatment and industrial facility.',
#    'key_objects': 'Circular water treatment facility with green sections, industrial machine with green metallic parts, fenced enclosure.'},
#   {'start_timestamp': '104.36s',
#    'end_timestamp': '109.82s',
#    'sentiment': 'Neutral',
#    'scene_theme': 'Corporate',
#    'characters': 'None',
#    'summary': "The latter part of the segment focuses on the branding of PCL Construction. The logo and slogan 'Together We Build Success' are prominently displayed against a white background.",
#    'actions': 'Transition from industrial scene to corporate branding.',
#    'key_objects': 'PCL Construction logo and slogan displayed on a white background.'}]]

# %% [markdown]
# ## Configurability

# %% [markdown]
# ### Load client from existing manifest

# %%
from cobrapy import VideoClient

client = VideoClient(manifest="./path_to_your_video/_video_manifest.json")

# %% [markdown]
# ### Pre-process video with custom parameters

# %%
client.preprocess_video(
    output_directory="./output_dir",  # control where to save the manifest and other files
    segment_length=20,  # how long should each segment be in seconds
    fps=1,  # how many frames per second to sample from the video (i.e. 1 = 1 frame per second, 1/3 = 1 frame per 3 seconds)
    max_workers=10,  # how many threads to use for processing. Default is to use number of cores minus 1.
    allow_partial_segments=True,  # if False, the last segment will be discarded if it is shorter than segment_length
    overwrite_output=True,  # any files in a directory with the same name will be overwritten
)
# Out:
# (0.0ss) Preprocessing video Sport.mp4
# (0.0s)Setting processing parameters...
# (0.0ss) Preparing output directory
# (0.0ss) Generating segments...
# (0.1ss) Extracting audio...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client.preprocess_video(
#       2     output_directory="./output_dir",  # control where to save the manifest and other files
#       3     segment_length=20,  # how long should each segment be in seconds
#       4     fps=1,  # how many frames per second to sample from the video (i.e. 1 = 1 frame per second, 1/3 = 1 frame per 3 seconds)
#       5     max_workers=10,  # how many threads to use for processing. Default is to use number of cores minus 1.
#       6     allow_partial_segments=True,  # if False, the last segment will be discarded if it is shorter than segment_length
#       7     overwrite_output=True,  # any files in a directory with the same name will be overwritten
#       8 )
#
# File ~\OneDrive - Microsoft\AI\COBRA-B\cobrapy\cobrapy\video_client.py:147, in VideoClient.preprocess_video(self, output_directory, segment_length, fps, generate_transcripts_flag, max_workers, trim_to_nearest_second, allow_partial_segments, overwrite_output)
#     145 # split the audio
#     146 vc = VideoFileClip(self.manifest.source_video.path)
# --> 147 vc.audio.write_audiofile(audio_path, verbose=False, logger=None)
#     148 audio_file_size_mb = os.path.getsize(audio_path) / (1024 * 1024)
#     150 # if audio file is > 25MB, we need to split and process it in chunks
#
# File <decorator-gen-63>:2, in write_audiofile(self, filename, fps, nbytes, buffersize, codec, bitrate, ffmpeg_params, write_logfile, verbose, logger)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\audio\AudioClip.py:206, in AudioClip.write_audiofile(self, filename, fps, nbytes, buffersize, codec, bitrate, ffmpeg_params, write_logfile, verbose, logger)
#     201     except KeyError:
#     202         raise ValueError("MoviePy couldn't find the codec associated "
#     203                          "with the filename. Provide the 'codec' "
#     204                          "parameter in write_audiofile.")
# --> 206 return ffmpeg_audiowrite(self, filename, fps, nbytes, buffersize,
#     207                          codec=codec, bitrate=bitrate,
#     208                          write_logfile=write_logfile, verbose=verbose,
#     209                          ffmpeg_params=ffmpeg_params,
#     210                          logger=logger)
#
# File <decorator-gen-27>:2, in ffmpeg_audiowrite(clip, filename, fps, nbytes, buffersize, codec, bitrate, write_logfile, verbose, ffmpeg_params, logger)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\audio\io\ffmpeg_audiowriter.py:166, in ffmpeg_audiowrite(clip, filename, fps, nbytes, buffersize, codec, bitrate, write_logfile, verbose, ffmpeg_params, logger)
#     160 logger(message="MoviePy - Writing audio in %s" % filename)
#     161 writer = FFMPEG_AudioWriter(filename, fps, nbytes, clip.nchannels,
#     162                             codec=codec, bitrate=bitrate,
#     163                             logfile=logfile,
#     164                             ffmpeg_params=ffmpeg_params)
# --> 166 for chunk in clip.iter_chunks(chunksize=buffersize,
#     167                               quantize=True,
#     168                               nbytes=nbytes, fps=fps,
#     169                               logger=logger):
#     170     writer.write_frames(chunk)
#     172 writer.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\audio\AudioClip.py:85, in AudioClip.iter_chunks(self, chunksize, chunk_duration, fps, quantize, nbytes, logger)
#      83 assert(size <= chunksize)
#      84 tt = (1.0/fps)*np.arange(pospos[i], pospos[i+1])
# ---> 85 yield self.to_soundarray(tt, nbytes=nbytes, quantize=quantize,
#      86                             fps=fps, buffersize=chunksize)
#
# File <decorator-gen-62>:2, in to_soundarray(self, tt, fps, quantize, nbytes, buffersize)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\audio\AudioClip.py:127, in AudioClip.to_soundarray(self, tt, fps, quantize, nbytes, buffersize)
#     117 """
#     118 elif len(tt)> 1.5*buffersize:
#     119     nchunks = int(len(tt)/buffersize+1)
#    (...)
#     123                       for ttc in tt_chunks])
#     124 """
#     125 #print tt.max() - tt.min(), tt.min(), tt.max()
# --> 127 snd_array = self.get_frame(tt)
#     129 if quantize:
#     130     snd_array = np.maximum(-0.99, np.minimum(0.99, snd_array))
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\audio\io\AudioFileClip.py:77, in AudioFileClip.__init__.<locals>.<lambda>(t)
#      74 self.end = self.reader.duration
#      75 self.buffersize = self.reader.buffersize
# ---> 77 self.make_frame = lambda t: self.reader.get_frame(t)
#      78 self.nchannels = self.reader.nchannels
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\moviepy\audio\io\readers.py:189, in FFMPEG_AudioReader.get_frame(self, tt)
#     186     self.buffer_around(fr_max)
#     188 try:
# --> 189     result = np.zeros((len(tt),self.nchannels))
#     190     indices = frames - self.buffer_startframe
#     191     if len(self.buffer) < self.buffersize // 2:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Parallel Analysis
#
# Analyses that have the analysis_sequence value of "mapreduce" can be run in parallel using async patterns. Throughput and parrallelism will be constrained by the rate limits of your LLM endpoint.

# %%
from cobrapy.analysis import BasicSummary

basic_config = BasicSummary()

basic_summary = client.analyze_video(basic_config, run_async=True)

# %% [markdown]
# ### Customizing an existing analysis configuration

# %%
from cobrapy.analysis import BasicSummary

# Load the default configuration
customizable_config = BasicSummary()

# Output the config values
customizable_config.model_dump()

# %%
# Customize the configuration
customizable_config.lens_prompt = "Analyze the video from the perspective of a wildlife documentarian. Describe any behaviors -- whether from animals, humans or anything else as though you are preparing for a Discovery Channel documentary. In addition to the normal summary, provide a draft script of a narration for the video."

customizable_config.results_template = {
    "segment_summary": "Text summary of what is happening in the clip segment.",
    "narration": "Draft narration script for the segment. In the style of Morgan Freeman or David Attenborough.",
}

customizable_config.run_final_summary = True

customizable_config.summary_prompt = "This video is from a comedy prank television show. Your job is to summarize the video based on the provided segment summaries. Explain the joke. Your summary should 2-3 sentences max."

# %%
documentary_summary = client.analyze_video(customizable_config, run_async=True)
documentary_summary

# %%
from pprint import pprint

pprint(client.manifest.final_summary)

# %% [markdown]
# ### Running a sequential / refine analysis

# %%
from cobrapy import VideoClient

client = VideoClient(video_path="C:\\videos\\PCL2.mp4")

manifest = client.preprocess_video(
    segment_length=30,
    fps=0.33,
    overwrite_output=True,
)

# %%
from cobrapy.analysis.chapter_summary import ChapterAnalysis

chapter_config = ChapterAnalysis()
chapter_summary = client.analyze_video(chapter_config)
